# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.7 MB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.3.15-cp38-cp38-win_amd64.whl (274 kB)
#      -------------------------------------- 274.4/274.4 KB 1.9 MB/s eta 0:00:00
# Collecting click
#   Using cached click-8.1.2-py3-none-any.whl (96 kB)
# Requirement already satisfied: joblib in d:\projects\python projects\pythonproject-3.8\venv\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in d:\projects\python projects\pythonproject-3.8\venv\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.2 nltk-3.7 regex-2022.3.15 tqdm-4.64.0

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('dataset/train_preprocessed.csv')
data.dropna(inplace = True)

# %%
MAX_NB_WORDS = 11000
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(data['text'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 6612 unique tokens.

# %%
word_index
# Out:
# {'information': 1,
#  'use': 2,
#  'service': 3,
#  'site': 4,
#  'third': 5,
#  'personal': 6,
#  'party': 7,
#  'privacy': 8,
#  'collect': 9,
#  'u': 10,
#  'provide': 11,
#  'address': 12,
#  'website': 13,
#  'policy': 14,
#  'user': 15,
#  'web': 16,
#  'email': 17,
#  'personally': 18,
#  'services': 19,
#  'identifiable': 20,
#  'cooky': 21,
#  'share': 22,
#  'online': 23,
#  'com': 24,
#  'data': 25,
#  'account': 26,
#  'access': 27,
#  'time': 28,
#  'also': 29,
#  'advertising': 30,
#  'company': 31,
#  'e': 32,
#  'contact': 33,
#  'request': 34,
#  'opt': 35,
#  'please': 36,
#  'collected': 37,
#  'device': 38,
#  'certain': 39,
#  'browser': 40,
#  'content': 41,
#  'including': 42,
#  'receive': 43,
#  'product': 44,
#  'mail': 45,
#  'visit': 46,
#  'us': 47,
#  'name': 48,
#  'page': 49,
#  'used': 50,
#  'number': 51,
#  'provider': 52,
#  'order': 53,
#  'law': 54,
#  'change': 55,
#  'ad': 56,
#  'marketing': 57,
#  'and': 58,
#  'purpose': 59,
#  'you': 60,
#  'or': 61,
#  'automatically': 62,
#  'cookies': 63,
#  'business': 64,
#  'mobile': 65,
#  'using': 66,
#  'disclose': 67,
#  'help': 68,
#  'out': 69,
#  'customer': 70,
#  'technology': 71,
#  'sites': 72,
#  'send': 73,
#  'computer': 74,
#  'security': 75,
#  'credit': 76,
#  'type': 77,
#  'ip': 78,
#  'internet': 79,
#  'choose': 80,
#  'link': 81,
#  'make': 82,
#  'communication': 83,
#  'protect': 84,
#  'non': 85,
#  'feature': 86,
#  'card': 87,
#  'health': 88,
#  'store': 89,
#  'right': 90,
#  'message': 91,
#  'location': 92,
#  'child': 93,
#  'offer': 94,
#  'advertiser': 95,
#  'activity': 96,
#  'social': 97,
#  'provided': 98,
#  'visitor': 99,
#  'notice': 100,
#  'one': 101,
#  'advertisement': 102,
#  'interest': 103,
#  'application': 104,
#  'medianews': 105,
#  'partner': 106,
#  'post': 107,
#  'consent': 108,
#  'network': 109,
#  'public': 110,
#  'allow': 111,
#  'required': 112,
#  'practice': 113,
#  'age': 114,
#  'submit': 115,
#  'term': 116,
#  'improve': 117,
#  'process': 118,
#  'following': 119,
#  'example': 120,
#  'new': 121,
#  'tracking': 122,
#  'legal': 123,
#  'experience': 124,
#  'cookie': 125,
#  'regarding': 126,
#  'purchase': 127,
#  'google': 128,
#  'track': 129,
#  's': 130,
#  'click': 131,
#  'websites': 132,
#  'collection': 133,
#  'system': 134,
#  'without': 135,
#  'parties': 136,
#  'include': 137,
#  'identify': 138,
#  '13': 139,
#  'transaction': 140,
#  'disclosure': 141,
#  'like': 142,
#  'control': 143,
#  'connection': 144,
#  'demographic': 145,
#  'purposes': 146,
#  'necessary': 147,
#  'via': 148,
#  'register': 149,
#  'see': 150,
#  'payment': 151,
#  'www': 152,
#  'registration': 153,
#  'otherwise': 154,
#  'participate': 155,
#  'date': 156,
#  'usage': 157,
#  'california': 158,
#  'search': 159,
#  'beacon': 160,
#  'promotional': 161,
#  'parent': 162,
#  'specific': 163,
#  'affiliate': 164,
#  'in': 165,
#  'promotion': 166,
#  'aggregate': 167,
#  'part': 168,
#  'set': 169,
#  'newsletter': 170,
#  'shared': 171,
#  'directly': 172,
#  'log': 173,
#  'wish': 174,
#  'update': 175,
#  'ask': 176,
#  'related': 177,
#  'individual': 178,
#  'preference': 179,
#  'profile': 180,
#  'want': 181,
#  'providing': 182,
#  'program': 183,
#  'behalf': 184,
#  'question': 185,
#  'delete': 186,
#  'within': 187,
#  'choice': 188,
#  'take': 189,
#  'available': 190,
#  'server': 191,
#  'to': 192,
#  'list': 193,
#  'phone': 194,
#  'way': 195,
#  'telephone': 196,
#  'based': 197,
#  'applicable': 198,
#  'record': 199,
#  'gather': 200,
#  'place': 201,
#  'medium': 202,
#  'similar': 203,
#  'others': 204,
#  'described': 205,
#  'contest': 206,
#  'understand': 207,
#  'setting': 208,
#  'state': 209,
#  'give': 210,
#  'inc': 211,
#  'transfer': 212,
#  'outside': 213,
#  'review': 214,
#  'comply': 215,
#  'receiving': 216,
#  'material': 217,
#  'flash': 218,
#  'sweepstakes': 219,
#  'member': 220,
#  'software': 221,
#  'relevant': 222,
#  'unsubscribe': 223,
#  'research': 224,
#  'apps': 225,
#  'enter': 226,
#  'password': 227,
#  'survey': 228,
#  'g': 229,
#  'whether': 230,
#  'form': 231,
#  'respond': 232,
#  'http': 233,
#  'analytics': 234,
#  'anonymous': 235,
#  'however': 236,
#  'subject': 237,
#  'need': 238,
#  'measure': 239,
#  'would': 240,
#  'code': 241,
#  'direct': 242,
#  'products': 243,
#  'maintain': 244,
#  'responsible': 245,
#  'event': 246,
#  'statement': 247,
#  'sign': 248,
#  'general': 249,
#  'analyze': 250,
#  'section': 251,
#  'area': 252,
#  'file': 253,
#  'sharing': 254,
#  'barnes': 255,
#  'obtain': 256,
#  'perform': 257,
#  'united': 258,
#  'appropriate': 259,
#  'noble': 260,
#  'fsd': 261,
#  'sell': 262,
#  'secure': 263,
#  'apply': 264,
#  'stored': 265,
#  'serve': 266,
#  'notify': 267,
#  'requested': 268,
#  'able': 269,
#  'identifying': 270,
#  'unique': 271,
#  'users': 272,
#  'another': 273,
#  'visiting': 274,
#  'support': 275,
#  'aggregated': 276,
#  'local': 277,
#  'prevent': 278,
#  'organization': 279,
#  'deliver': 280,
#  'better': 281,
#  'action': 282,
#  'mailing': 283,
#  'particular': 284,
#  'processing': 285,
#  'special': 286,
#  'view': 287,
#  'postal': 288,
#  'financial': 289,
#  'operating': 290,
#  'person': 291,
#  'safety': 292,
#  'limited': 293,
#  'option': 294,
#  'app': 295,
#  'enforcement': 296,
#  'pixel': 297,
#  'administer': 298,
#  'group': 299,
#  'manage': 300,
#  'interactive': 301,
#  'agree': 302,
#  'electronic': 303,
#  'additional': 304,
#  'honda': 305,
#  'enable': 306,
#  'require': 307,
#  'well': 308,
#  'such': 309,
#  'beacons': 310,
#  'property': 311,
#  'cannot': 312,
#  'year': 313,
#  'comment': 314,
#  'mean': 315,
#  'storage': 316,
#  'technical': 317,
#  'sent': 318,
#  'facebook': 319,
#  'might': 320,
#  'jibjab': 321,
#  'complete': 322,
#  'activities': 323,
#  'learn': 324,
#  'co': 325,
#  'display': 326,
#  'science': 327,
#  'features': 328,
#  'pin': 329,
#  'addition': 330,
#  'unless': 331,
#  '1': 332,
#  'many': 333,
#  'know': 334,
#  'accept': 335,
#  'consumer': 336,
#  'read': 337,
#  'various': 338,
#  'disable': 339,
#  'note': 340,
#  'reserve': 341,
#  'function': 342,
#  'believe': 343,
#  'below': 344,
#  'networking': 345,
#  'entity': 346,
#  'instruction': 347,
#  'it': 348,
#  'companies': 349,
#  'yahoo': 350,
#  'sending': 351,
#  'transferred': 352,
#  'recognize': 353,
#  'communicate': 354,
#  'fulfill': 355,
#  'safe': 356,
#  'protection': 357,
#  'different': 358,
#  'here': 359,
#  'permission': 360,
#  'visited': 361,
#  'correct': 362,
#  'technologies': 363,
#  'identifier': 364,
#  'org': 365,
#  'source': 366,
#  'fraud': 367,
#  'disclosed': 368,
#  'must': 369,
#  'traffic': 370,
#  'opportunity': 371,
#  'vendor': 372,
#  'protocol': 373,
#  'targeted': 374,
#  'keep': 375,
#  'subscription': 376,
#  'partners': 377,
#  'tulsaworld': 378,
#  'operate': 379,
#  'srl': 380,
#  'future': 381,
#  'unauthorized': 382,
#  'conduct': 383,
#  'database': 384,
#  'registered': 385,
#  'reasonable': 386,
#  'knowingly': 387,
#  'posted': 388,
#  'response': 389,
#  "child's": 390,
#  'preferences': 391,
#  'personalize': 392,
#  'interaction': 393,
#  'customize': 394,
#  'allstate': 395,
#  'linked': 396,
#  'affiliated': 397,
#  'associated': 398,
#  'made': 399,
#  'remove': 400,
#  'family': 401,
#  'text': 402,
#  'interact': 403,
#  'last': 404,
#  'gender': 405,
#  'country': 406,
#  'good': 407,
#  'tool': 408,
#  'providers': 409,
#  'kaleida': 410,
#  'ensure': 411,
#  'first': 412,
#  'id': 413,
#  'applies': 414,
#  'people': 415,
#  'agreement': 416,
#  'work': 417,
#  'affiliates': 418,
#  'posting': 419,
#  'viewed': 420,
#  'advertisers': 421,
#  'analysis': 422,
#  'clear': 423,
#  'wireless': 424,
#  'publicly': 425,
#  'voluntarily': 426,
#  'government': 427,
#  'includes': 428,
#  'notification': 429,
#  'updated': 430,
#  'contacting': 431,
#  'monitor': 432,
#  'aware': 433,
#  'harbor': 434,
#  'determine': 435,
#  'billing': 436,
#  'for': 437,
#  'shopping': 438,
#  'free': 439,
#  'follow': 440,
#  'create': 441,
#  'zip': 442,
#  'rights': 443,
#  'game': 444,
#  'functionality': 445,
#  'relationship': 446,
#  'authorized': 447,
#  'except': 448,
#  'release': 449,
#  'upon': 450,
#  'court': 451,
#  'national': 452,
#  'modify': 453,
#  'geographic': 454,
#  'result': 455,
#  'digital': 456,
#  'community': 457,
#  'collectively': 458,
#  'sidearm': 459,
#  'addresses': 460,
#  'allows': 461,
#  'accordance': 462,
#  'covered': 463,
#  'generally': 464,
#  'portion': 465,
#  'promotions': 466,
#  'home': 467,
#  'resident': 468,
#  'session': 469,
#  'serving': 470,
#  'military': 471,
#  "children's": 472,
#  'management': 473,
#  'download': 474,
#  'enforce': 475,
#  'paymentech': 476,
#  'agent': 477,
#  'subscriber': 478,
#  'practices': 479,
#  'either': 480,
#  'gifs': 481,
#  'act': 482,
#  'bank': 483,
#  'offers': 484,
#  'merchant': 485,
#  'news': 486,
#  'current': 487,
#  'sale': 488,
#  'forum': 489,
#  'personalized': 490,
#  'contests': 491,
#  'located': 492,
#  'chase': 493,
#  'administration': 494,
#  'select': 495,
#  'protected': 496,
#  'federal': 497,
#  'them': 498,
#  'contain': 499,
#  'microsoft': 500,
#  'important': 501,
#  'above': 502,
#  'internal': 503,
#  'received': 504,
#  'platform': 505,
#  'agency': 506,
#  'chat': 507,
#  'comments': 508,
#  'policies': 509,
#  'effective': 510,
#  'video': 511,
#  'physical': 512,
#  'anyone': 513,
#  'offering': 514,
#  'a': 515,
#  'behavior': 516,
#  'among': 517,
#  'stop': 518,
#  'assist': 519,
#  'offered': 520,
#  'operated': 521,
#  'possible': 522,
#  'behavioral': 523,
#  'effectiveness': 524,
#  'subscribe': 525,
#  'asset': 526,
#  'clicking': 527,
#  'applications': 528,
#  'domain': 529,
#  'respect': 530,
#  'department': 531,
#  'american': 532,
#  'placed': 533,
#  'branded': 534,
#  'asked': 535,
#  'method': 536,
#  'york': 537,
#  'identified': 538,
#  'instagram': 539,
#  'guardian': 540,
#  'longer': 541,
#  'america': 542,
#  'delivery': 543,
#  'feedback': 544,
#  'li': 545,
#  'version': 546,
#  'written': 547,
#  'cin': 548,
#  'at': 549,
#  'condition': 550,
#  'needed': 551,
#  'commercial': 552,
#  'street': 553,
#  'ul': 554,
#  'statistical': 555,
#  'inform': 556,
#  'case': 557,
#  'intended': 558,
#  'corporate': 559,
#  'job': 560,
#  'info': 561,
#  'small': 562,
#  'tailor': 563,
#  "user's": 564,
#  'persistent': 565,
#  'pages': 566,
#  'standard': 567,
#  'merger': 568,
#  'submitted': 569,
#  'reddit': 570,
#  'problem': 571,
#  'friend': 572,
#  'ssl': 573,
#  'states': 574,
#  'decide': 575,
#  'tell': 576,
#  'requires': 577,
#  'interests': 578,
#  'newsletters': 579,
#  'amazon': 580,
#  'limitation': 581,
#  'supply': 582,
#  'sponsor': 583,
#  'protecting': 584,
#  'enhance': 585,
#  'administrative': 586,
#  'market': 587,
#  'drive': 588,
#  'tailored': 589,
#  'full': 590,
#  'contractor': 591,
#  'committed': 592,
#  'retain': 593,
#  'we': 594,
#  'surveys': 595,
#  'remember': 596,
#  'truste': 597,
#  'informatio': 598,
#  'transmission': 599,
#  'report': 600,
#  'f': 601,
#  'inquiry': 602,
#  'always': 603,
#  'i': 604,
#  'offline': 605,
#  'add': 606,
#  'connect': 607,
#  'fulfillment': 608,
#  'history': 609,
#  'changes': 610,
#  'publication': 611,
#  'fool': 612,
#  'line': 613,
#  'deleted': 614,
#  'aol': 615,
#  'provides': 616,
#  'br': 617,
#  'browsing': 618,
#  'valve': 619,
#  'hard': 620,
#  'course': 621,
#  'participation': 622,
#  'call': 623,
#  'settings': 624,
#  'image': 625,
#  'detail': 626,
#  'whenever': 627,
#  'ability': 628,
#  'sometimes': 629,
#  'customers': 630,
#  'combine': 631,
#  'manner': 632,
#  'reporting': 633,
#  'subsidiary': 634,
#  'governed': 635,
#  'sony': 636,
#  'show': 637,
#  'assets': 638,
#  'currently': 639,
#  'treat': 640,
#  'board': 641,
#  'reasonably': 642,
#  'viewing': 643,
#  'called': 644,
#  'day': 645,
#  'so': 646,
#  'become': 647,
#  'care': 648,
#  'reviews': 649,
#  'prior': 650,
#  "users'": 651,
#  'if': 652,
#  'birth': 653,
#  'potential': 654,
#  'limit': 655,
#  'facilitate': 656,
#  'smithsonian': 657,
#  'communications': 658,
#  'permitted': 659,
#  'official': 660,
#  'violation': 661,
#  'coordinator': 662,
#  'accessing': 663,
#  'forth': 664,
#  'develop': 665,
#  'directed': 666,
#  'llc': 667,
#  'tag': 668,
#  'across': 669,
#  'lynda': 670,
#  'known': 671,
#  'guarantee': 672,
#  'compliance': 673,
#  'logging': 674,
#  'relating': 675,
#  'industry': 676,
#  'variety': 677,
#  'b': 678,
#  'c': 679,
#  'illegal': 680,
#  'risk': 681,
#  'confidentiality': 682,
#  'participating': 683,
#  'revised': 684,
#  'even': 685,
#  'boards': 686,
#  'ten': 687,
#  'healthcare': 688,
#  'concern': 689,
#  'children': 690,
#  'integrity': 691,
#  'meet': 692,
#  'complaint': 693,
#  'exercise': 694,
#  'statistic': 695,
#  'nyt': 696,
#  'two': 697,
#  'go': 698,
#  'item': 699,
#  'automatic': 700,
#  'copy': 701,
#  'de': 702,
#  'the': 703,
#  'gov': 704,
#  'requests': 705,
#  'buy': 706,
#  'membership': 707,
#  'on': 708,
#  'write': 709,
#  'performance': 710,
#  'identity': 711,
#  'curse': 712,
#  'permit': 713,
#  'procedure': 714,
#  'html': 715,
#  'voluntary': 716,
#  'bottom': 717,
#  'suite': 718,
#  'along': 719,
#  'etc': 720,
#  'basis': 721,
#  'encourage': 722,
#  'best': 723,
#  'employee': 724,
#  'url': 725,
#  'ways': 726,
#  'doubleclick': 727,
#  'times': 728,
#  '2': 729,
#  'entry': 730,
#  'advertisements': 731,
#  'find': 732,
#  'check': 733,
#  'return': 734,
#  'debit': 735,
#  'open': 736,
#  'ads': 737,
#  'choices': 738,
#  '800': 739,
#  'investigation': 740,
#  'effort': 741,
#  'motley': 742,
#  'resume': 743,
#  'rule': 744,
#  'interested': 745,
#  'world': 746,
#  'latin': 747,
#  'subpoena': 748,
#  'investigate': 749,
#  'pattern': 750,
#  'diagnose': 751,
#  'of': 752,
#  'twitter': 753,
#  'referred': 754,
#  'involved': 755,
#  'still': 756,
#  'operation': 757,
#  'messages': 758,
#  'forums': 759,
#  'student': 760,
#  'zacks': 761,
#  'long': 762,
#  'archive': 763,
#  'hearst': 764,
#  'username': 765,
#  'pre': 766,
#  'purchasing': 767,
#  'defend': 768,
#  'accessed': 769,
#  'object': 770,
#  'engage': 771,
#  'nformation': 772,
#  'governmental': 773,
#  'circumstance': 774,
#  'sold': 775,
#  'immediately': 776,
#  'regulation': 777,
#  'get': 778,
#  'commercially': 779,
#  'reason': 780,
#  'do': 781,
#  'safeguard': 782,
#  'identifies': 783,
#  'extent': 784,
#  'step': 785,
#  'tags': 786,
#  'meredith': 787,
#  'prefer': 788,
#  'decline': 789,
#  'authority': 790,
#  'contained': 791,
#  'submission': 792,
#  'education': 793,
#  'food': 794,
#  'trends': 795,
#  'faith': 796,
#  'private': 797,
#  'european': 798,
#  'cases': 799,
#  'discussion': 800,
#  'continued': 801,
#  'writing': 802,
#  'library': 803,
#  'lawful': 804,
#  'audience': 805,
#  'authorize': 806,
#  'd': 807,
#  'language': 808,
#  'notmc': 809,
#  'terms': 810,
#  'rent': 811,
#  'files': 812,
#  'employ': 813,
#  'leave': 814,
#  'acquisition': 815,
#  'union': 816,
#  'servers': 817,
#  'shall': 818,
#  'article': 819,
#  'run': 820,
#  'as': 821,
#  'orders': 822,
#  'p': 823,
#  'properly': 824,
#  'sources': 825,
#  'transmit': 826,
#  'advantage': 827,
#  'entertainment': 828,
#  'processed': 829,
#  'questions': 830,
#  'gathered': 831,
#  'programs': 832,
#  "computer's": 833,
#  'opting': 834,
#  'removed': 835,
#  'emails': 836,
#  'belief': 837,
#  'every': 838,
#  'associate': 839,
#  'messaging': 840,
#  '3': 841,
#  'could': 842,
#  'shipping': 843,
#  'solely': 844,
#  'improving': 845,
#  'periodically': 846,
#  'customized': 847,
#  'specifically': 848,
#  'adobe': 849,
#  'listed': 850,
#  'obtained': 851,
#  "site's": 852,
#  'insurance': 853,
#  'box': 854,
#  'cardholder': 855,
#  'period': 856,
#  'verify': 857,
#  'elect': 858,
#  'login': 859,
#  'edit': 860,
#  'compile': 861,
#  'gift': 862,
#  'trend': 863,
#  'logged': 864,
#  'areas': 865,
#  'hardware': 866,
#  'refuse': 867,
#  'instance': 868,
#  'describes': 869,
#  'maintained': 870,
#  'status': 871,
#  'w': 872,
#  'aboutads': 873,
#  'center': 874,
#  'attempt': 875,
#  'someone': 876,
#  'reference': 877,
#  'referring': 878,
#  'controlled': 879,
#  'socket': 880,
#  'layer': 881,
#  'selected': 882,
#  'carefully': 883,
#  'responsibility': 884,
#  'accessible': 885,
#  'officer': 886,
#  'navigate': 887,
#  'ted': 888,
#  'amount': 889,
#  'sole': 890,
#  'existing': 891,
#  'nature': 892,
#  'making': 893,
#  'city': 894,
#  'patterns': 895,
#  'institution': 896,
#  'jurisdiction': 897,
#  'kind': 898,
#  'unaffiliated': 899,
#  'stream': 900,
#  'washingtonian': 901,
#  'cover': 902,
#  'transmitted': 903,
#  'updates': 904,
#  'accepting': 905,
#  'never': 906,
#  'systems': 907,
#  'continue': 908,
#  'authorization': 909,
#  'clicked': 910,
#  'transactional': 911,
#  'photo': 912,
#  'collecting': 913,
#  'administrator': 914,
#  'disney': 915,
#  'opted': 916,
#  'significant': 917,
#  'created': 918,
#  'clickstream': 919,
#  'alert': 920,
#  'retained': 921,
#  'maintaining': 922,
#  'games': 923,
#  'nbcuniversal': 924,
#  'caribou': 925,
#  'included': 926,
#  'often': 927,
#  'loss': 928,
#  'mechanism': 929,
#  'designed': 930,
#  'analyzing': 931,
#  'although': 932,
#  'st': 933,
#  'brochure': 934,
#  'requesting': 935,
#  'records': 936,
#  'subsidiaries': 937,
#  'generated': 938,
#  'automated': 939,
#  'networks': 940,
#  'hosted': 941,
#  '5': 942,
#  'visitors': 943,
#  'maintenance': 944,
#  'refer': 945,
#  'responding': 946,
#  'dealer': 947,
#  'enables': 948,
#  'treatment': 949,
#  'block': 950,
#  'displayed': 951,
#  'sponsored': 952,
#  'bing': 953,
#  'piece': 954,
#  'up': 955,
#  'requirement': 956,
#  'owned': 957,
#  'by': 958,
#  'disclosing': 959,
#  'category': 960,
#  'calendar': 961,
#  'found': 962,
#  'receipt': 963,
#  'allergy': 964,
#  'misuse': 965,
#  'warrant': 966,
#  'threat': 967,
#  'laws': 968,
#  'eu': 969,
#  'utilize': 970,
#  'save': 971,
#  'changing': 972,
#  'plug': 973,
#  'suspected': 974,
#  'registering': 975,
#  'confirm': 976,
#  '4': 977,
#  'functions': 978,
#  'nytimes': 979,
#  'butler': 980,
#  'names': 981,
#  'graphic': 982,
#  'n': 983,
#  'sensitive': 984,
#  'screen': 985,
#  'obligation': 986,
#  'bankruptcy': 987,
#  'initiative': 988,
#  'trust': 989,
#  'corporation': 990,
#  'submitting': 991,
#  'transactions': 992,
#  'ii': 993,
#  'feel': 994,
#  'agents': 995,
#  'regulatory': 996,
#  'managing': 997,
#  'guest': 998,
#  'imdb': 999,
#  'nook': 1000,
#  ...}

# %%
X = tokenizer.texts_to_sequences(data['text'].values)
print(len(X[20]))
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', X.shape)
# Out:
# 35
# Shape of data tensor: (19357, 100)

# %%
Y = pd.get_dummies(data['class']).values
print('Shape of label tensor:', Y.shape)
# Out:
# Shape of label tensor: (19357, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42, stratify=Y)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (15485, 100) (15485, 10)
# (3872, 100) (3872, 10)

# %%
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(LSTM(50, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(Y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          1100000
#
#  lstm (LSTM)                 (None, 50)                30200
#
#  dense (Dense)               (None, 10)                510
#
# =================================================================
# Total params: 1,130,710
# Trainable params: 1,130,710
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epochs = 5
batch_size = 64

history = model.fit(
    X_train, Y_train, 
    epochs=epochs, batch_size=batch_size,
    validation_split=0.2,
    callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)]
)
# Out:
# Epoch 1/5
# 194/194 [==============================] - 15s 68ms/step - loss: 1.5062 - categorical_accuracy: 0.5017 - val_loss: 1.0794 - val_categorical_accuracy: 0.6571
# Epoch 2/5
# 194/194 [==============================] - 13s 66ms/step - loss: 0.8972 - categorical_accuracy: 0.7225 - val_loss: 0.8263 - val_categorical_accuracy: 0.7588
# Epoch 3/5
# 194/194 [==============================] - 13s 67ms/step - loss: 0.6566 - categorical_accuracy: 0.8034 - val_loss: 0.7427 - val_categorical_accuracy: 0.7830
# Epoch 4/5
# 194/194 [==============================] - 14s 70ms/step - loss: 0.5035 - categorical_accuracy: 0.8473 - val_loss: 0.6755 - val_categorical_accuracy: 0.7982
# Epoch 5/5
# 194/194 [==============================] - 13s 69ms/step - loss: 0.4138 - categorical_accuracy: 0.8753 - val_loss: 0.6702 - val_categorical_accuracy: 0.8040

# %%
accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 121/121 [==============================] - 1s 8ms/step - loss: 0.6821 - categorical_accuracy: 0.8004
# Test set
#   Loss: 0.682
#   Accuracy: 0.800
