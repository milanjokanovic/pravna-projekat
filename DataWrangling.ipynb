# %%
def extract_data(extracted_data, data):
    for index in range(len(data)):
        el = data[6][index]
        json_load = (json.loads(el))
        if(len(json_load.keys()) == 1):
            for key in json_load.keys():
                inner_element = json_load[key]
                if('selectedText' in inner_element.keys()):
                    if(inner_element['startIndexInSegment'] != -1):
                        extracted_data.append([inner_element['selectedText'], data[5][index]])
        if(len(json_load.keys()) > 1):
            text_data = ''
            for key in json_load.keys():
                inner_element = json_load[key]
                if('selectedText' in inner_element.keys()):
                    if(inner_element['startIndexInSegment'] != -1):
                        text_data = text_data + " " + inner_element['selectedText']
            if(text_data != ''):
                extracted_data.append([text_data, data[5][index]])

# %%
import pandas as pd
import json
import glob

glued_data = pd.DataFrame()
directoryPath = 'annotations/'

extracted_data = []
for file_name in glob.glob(directoryPath + '*.csv'):
    data = pd.read_csv(file_name, low_memory=False, header=None)
    extract_data(extracted_data, data)

# %%
header = ["text", "class"]
wrangled_data = pd.DataFrame(extracted_data, columns=header)
wrangled_data.drop_duplicates(subset ="text",
                     keep = 'first', inplace = True)
wrangled_data
# Out:
#                                                     text  \
# 0      Sci-News.com is committed to protecting and re...
# 2      Sci-News.com is committed to protecting and re...
# 3       Please note that these terms are subject to c...
# 4       nformation that you provide by filling in for...
# 5       nformation that you provide by filling in for...
# 6       information that you provide by filling in fo...
# 7       that you provide by filling in forms on our s...
# 8       that you provide by filling in forms on our s...
# 9       that you provide by filling in forms on our s...
# 10      that you provide by filling in forms on our s...
# 11              that correspondence we may keep a record
# 12                         record of that correspondence
# 13      if you contact us we may keep a record of tha...
# 14                                         location data
# 15                                          traffic data
# 16                            including, but not limited
# 17                  weblogs and other communication data
# 18      details of your visits to our site our site d...
# 19      details of your visits to our site our site l...
# 20      details of your visits to our site our site c...
# 21     Sci-News.com does not knowingly collect or sol...
# 22     Parents or guardians may contact us at privacy...
# 23     Sci-News.com does not knowingly collect or sol...
# 24     anyone under the age of 13. We assume that min...
# 26      Sci-News.com uses cookie technology if your b...
# 27      Sci-News.com uses uses cookie technology your...
# 28      A cookie is a small amount of data, which oft...
# 29     During the course of any visit to the Sci-News...
# 30      During the course of any visit to the Sci-New...
# 31      During the course of any visit to the Sci-New...
# ...                                                  ...
# 21458   collected removed online name, email address,...
# 21459   collected removed online home address a "unsu...
# 21460   collected removed online data collected regar...
# 21461                        any third party None shared
# 21462   upon the request of a visitor collected onlin...
# 21463   upon the request of a visitor collected onlin...
# 21464   The database is available for Mohegan Sun's u...
# 21465   ame, email address, home address t wish to be...
# 21466   data collected regarding areas of interest is...
# 21467   any third party and is available only to spec...
# 21468   data collected regarding areas of interest is...
# 21469   ame, email address, home address t wish to be...
# 21470                          name, a Collected sign up
# 21471                          address Collected sign up
# 21472   any third party. not shared that is not share...
# 21473   patrons may sign up All personal information ...
# 21474   All personal information collected at any Pla...
# 21475   nformation collected onlin information collec...
# 21476   nformation collected onlin patrons may sign u...
# 21477   any third party. Momentum member name, addres...
# 21478                                            updated
# 21479   Certain information, such as address or email...
# 21480   Certain information, such as address or email...
# 21481             ng Customer Service at 1.888.777.7920.
# 21482  This site is not intended for children. Childr...
# 21483                ersonal information do not children
# 21484  If you have a question regarding any of the ab...
# 21485                         information@mohegansun.com
# 21486  1 Mohegan Sun Boulevard Uncasville, CT 06382 F...
# 21487  1 Mohegan Sun Boulevard Uncasville, CT 06382 F...
#
#                                       class
# 0                                     Other
# 2                                     Other
# 3                             Policy Change
# 4                First Party Collection/Use
# 5                First Party Collection/Use
# 6                First Party Collection/Use
# 7                First Party Collection/Use
# 8                First Party Collection/Use
# 9                First Party Collection/Use
# 10               First Party Collection/Use
# 11                           Data Retention
# 12                           Data Retention
# 13               First Party Collection/Use
# 14               First Party Collection/Use
# 15               First Party Collection/Use
# 16               First Party Collection/Use
# 17               First Party Collection/Use
# 18               First Party Collection/Use
# 19               First Party Collection/Use
# 20               First Party Collection/Use
# 21     International and Specific Audiences
# 22                                    Other
# 23     International and Specific Audiences
# 24     International and Specific Audiences
# 26               First Party Collection/Use
# 27               First Party Collection/Use
# 28               First Party Collection/Use
# 29                                    Other
# 30               First Party Collection/Use
# 31               First Party Collection/Use
# ...                                     ...
# 21458            First Party Collection/Use
# 21459            First Party Collection/Use
# 21460            First Party Collection/Use
# 21461        Third Party Sharing/Collection
# 21462            First Party Collection/Use
# 21463            First Party Collection/Use
# 21464        Third Party Sharing/Collection
# 21465            First Party Collection/Use
# 21466            First Party Collection/Use
# 21467        Third Party Sharing/Collection
# 21468            First Party Collection/Use
# 21469            First Party Collection/Use
# 21470            First Party Collection/Use
# 21471            First Party Collection/Use
# 21472        Third Party Sharing/Collection
# 21473            First Party Collection/Use
# 21474        Third Party Sharing/Collection
# 21475            First Party Collection/Use
# 21476            First Party Collection/Use
# 21477        Third Party Sharing/Collection
# 21478        User Access, Edit and Deletion
# 21479        User Access, Edit and Deletion
# 21480        User Access, Edit and Deletion
# 21481                                 Other
# 21482  International and Specific Audiences
# 21483            First Party Collection/Use
# 21484                                 Other
# 21485                                 Other
# 21486                                 Other
# 21487                                 Other
#
# [20815 rows x 2 columns]

# %%
wrangled_data.to_csv('dataset/wrangled_data.csv', index=False)

# %%
df = pd.read_csv("dataset/wrangled_data.csv")
df
# Out:
#                                                     text  \
# 0      Sci-News.com is committed to protecting and re...
# 1      Sci-News.com is committed to protecting and re...
# 2       Please note that these terms are subject to c...
# 3       nformation that you provide by filling in for...
# 4       nformation that you provide by filling in for...
# 5       information that you provide by filling in fo...
# 6       that you provide by filling in forms on our s...
# 7       that you provide by filling in forms on our s...
# 8       that you provide by filling in forms on our s...
# 9       that you provide by filling in forms on our s...
# 10              that correspondence we may keep a record
# 11                         record of that correspondence
# 12      if you contact us we may keep a record of tha...
# 13                                         location data
# 14                                          traffic data
# 15                            including, but not limited
# 16                  weblogs and other communication data
# 17      details of your visits to our site our site d...
# 18      details of your visits to our site our site l...
# 19      details of your visits to our site our site c...
# 20     Sci-News.com does not knowingly collect or sol...
# 21     Parents or guardians may contact us at privacy...
# 22     Sci-News.com does not knowingly collect or sol...
# 23     anyone under the age of 13. We assume that min...
# 24      Sci-News.com uses cookie technology if your b...
# 25      Sci-News.com uses uses cookie technology your...
# 26      A cookie is a small amount of data, which oft...
# 27     During the course of any visit to the Sci-News...
# 28      During the course of any visit to the Sci-New...
# 29      During the course of any visit to the Sci-New...
# ...                                                  ...
# 20785   collected removed online name, email address,...
# 20786   collected removed online home address a "unsu...
# 20787   collected removed online data collected regar...
# 20788                        any third party None shared
# 20789   upon the request of a visitor collected onlin...
# 20790   upon the request of a visitor collected onlin...
# 20791   The database is available for Mohegan Sun's u...
# 20792   ame, email address, home address t wish to be...
# 20793   data collected regarding areas of interest is...
# 20794   any third party and is available only to spec...
# 20795   data collected regarding areas of interest is...
# 20796   ame, email address, home address t wish to be...
# 20797                          name, a Collected sign up
# 20798                          address Collected sign up
# 20799   any third party. not shared that is not share...
# 20800   patrons may sign up All personal information ...
# 20801   All personal information collected at any Pla...
# 20802   nformation collected onlin information collec...
# 20803   nformation collected onlin patrons may sign u...
# 20804   any third party. Momentum member name, addres...
# 20805                                            updated
# 20806   Certain information, such as address or email...
# 20807   Certain information, such as address or email...
# 20808             ng Customer Service at 1.888.777.7920.
# 20809  This site is not intended for children. Childr...
# 20810                ersonal information do not children
# 20811  If you have a question regarding any of the ab...
# 20812                         information@mohegansun.com
# 20813  1 Mohegan Sun Boulevard Uncasville, CT 06382 F...
# 20814  1 Mohegan Sun Boulevard Uncasville, CT 06382 F...
#
#                                       class
# 0                                     Other
# 1                                     Other
# 2                             Policy Change
# 3                First Party Collection/Use
# 4                First Party Collection/Use
# 5                First Party Collection/Use
# 6                First Party Collection/Use
# 7                First Party Collection/Use
# 8                First Party Collection/Use
# 9                First Party Collection/Use
# 10                           Data Retention
# 11                           Data Retention
# 12               First Party Collection/Use
# 13               First Party Collection/Use
# 14               First Party Collection/Use
# 15               First Party Collection/Use
# 16               First Party Collection/Use
# 17               First Party Collection/Use
# 18               First Party Collection/Use
# 19               First Party Collection/Use
# 20     International and Specific Audiences
# 21                                    Other
# 22     International and Specific Audiences
# 23     International and Specific Audiences
# 24               First Party Collection/Use
# 25               First Party Collection/Use
# 26               First Party Collection/Use
# 27                                    Other
# 28               First Party Collection/Use
# 29               First Party Collection/Use
# ...                                     ...
# 20785            First Party Collection/Use
# 20786            First Party Collection/Use
# 20787            First Party Collection/Use
# 20788        Third Party Sharing/Collection
# 20789            First Party Collection/Use
# 20790            First Party Collection/Use
# 20791        Third Party Sharing/Collection
# 20792            First Party Collection/Use
# 20793            First Party Collection/Use
# 20794        Third Party Sharing/Collection
# 20795            First Party Collection/Use
# 20796            First Party Collection/Use
# 20797            First Party Collection/Use
# 20798            First Party Collection/Use
# 20799        Third Party Sharing/Collection
# 20800            First Party Collection/Use
# 20801        Third Party Sharing/Collection
# 20802            First Party Collection/Use
# 20803            First Party Collection/Use
# 20804        Third Party Sharing/Collection
# 20805        User Access, Edit and Deletion
# 20806        User Access, Edit and Deletion
# 20807        User Access, Edit and Deletion
# 20808                                 Other
# 20809  International and Specific Audiences
# 20810            First Party Collection/Use
# 20811                                 Other
# 20812                                 Other
# 20813                                 Other
# 20814                                 Other
#
# [20815 rows x 2 columns]
